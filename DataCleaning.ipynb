# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import csv
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile,join
print('You are using Pandas version', pd.__version__, '!')
# Out:
# You are using Pandas version 1.4.2 !

# %%
data = pd.read_csv('Temperature_change_Data.csv',  encoding = 'latin_1')
data = data.drop(labels = 0 ,axis = 0)
data
# Out:
#       Country_Code                             Country_Name  year  tem_change
# 1              ALB                                  Albania  1961       0.631
# 2              DZA                                  Algeria  1961       0.186
# 3              ASM                           American Samoa  1961      -0.014
# 4              AND                                  Andorra  1961       0.749
# 5              AGO                                   Angola  1961       0.053
# ...            ...                                      ...   ...         ...
# 16751          NaN        Low Income Food Deficit Countries  2019       1.244
# 16752          NaN  Net Food Importing Developing Countries  2019       1.412
# 16753          NaN                        Annex I countries  2019       1.627
# 16754          NaN                    Non-Annex I countries  2019       1.361
# 16755          NaN                                     OECD  2019       1.297
#
# [16755 rows x 4 columns]

# %%
metai = data.drop_duplicates(subset=['year'])
metai

#metai['year'].to_string(index=False)
# Out:
#                                 Country_Code  Country_Name              year  \
# 1                                        ALB       Albania              1961
# 44     HKG,"China, Hong Kong SAR",1961,0.047           NaN               NaN
# 284                                      AFG   Afghanistan              1962
# 568                                      AFG   Afghanistan              1963
# 771                                      ZAF  South Africa  1963+A773:C16747
# ...                                      ...           ...               ...
# 15336                                    AFG   Afghanistan              2015
# 15620                                    AFG   Afghanistan              2016
# 15904                                    AFG   Afghanistan              2017
# 16188                                    AFG   Afghanistan              2018
# 16472                                    AFG   Afghanistan              2019
#
#        tem_change
# 1           0.631
# ...

# %%
#atspausdinti duomenis 1970 metu

first = data.loc[data['year'] == '1970']
first
first_decade = first.nlargest(10, ['tem_change'])
first_decade
# Out:
#      Country_Code                Country_Name  year  tem_change
# 2661          IRN  Iran (Islamic Republic of)  1970       0.982
# 2719          OMN                        Oman  1970       0.957
# 2743          SPM   Saint Pierre and Miquelon  1970       0.944
# 2556          AFG                 Afghanistan  1970       0.858
# 2779          TUR                      Turkey  1970       0.855
# 2692          MRT                  Mauritania  1970       0.670
# 2662          IRQ                        Iraq  1970       0.638
# 2770          SYR        Syrian Arab Republic  1970       0.630
# 2583          BWA                    Botswana  1970       0.623
# 2590          CPV                  Cabo Verde  1970       0.608

# %%
first_decade.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Decade_1970.csv', encoding='utf-8')

# %%
second = data.loc[data['year'] == '1980']
second
second_decade=second.nlargest(10, ['tem_change'])
second_decade
# Out:
#      Country_Code Country_Name  year  tem_change
# 5589          SEN      Senegal  1980       0.967
# 5528          MLI         Mali  1980       0.963
# 5430          CPV   Cabo Verde  1980       0.957
# 5433          CAN       Canada  1980       0.921
# 5487          GRL    Greenland  1980       0.919
# 5407          ABW        Aruba  1980       0.888
# 5460          DJI     Djibouti  1980       0.882
# 5408          AUS    Australia  1980       0.862
# 5481          GMB       Gambia  1980       0.861
# 5532          MRT   Mauritania  1980       0.857

# %%
second_decade.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Decade_1980.csv', encoding='utf-8')

# %%
third = data.loc[data['year'] == '1990']
third
third_decade = third.nlargest(10, ['tem_change'])
third_decade
# Out:
#      Country_Code                    Country_Name  year  tem_change
# 8299          DNK                         Denmark  1990       1.835
# 8240          AND                         Andorra  1990       1.734
# 8410          POL                          Poland  1990       1.712
# 8448          SWE                          Sweden  1990       1.695
# 8447          SJM  Svalbard and Jan Mayen Islands  1990       1.632
# 8323          DEU                         Germany  1990       1.571
# 8316          FRA                          France  1990       1.563
# 8388          NLD                     Netherlands  1990       1.563
# 8379          MNG                        Mongolia  1990       1.559
# 8458          TUN                         Tunisia  1990       1.556

# %%
third_decade.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Decade_1990.csv', encoding='utf-8')

# %%
fourth = data.loc[data['year'] == '2000']
fourth
fourth_decade=fourth.nlargest(10, ['tem_change'])
fourth_decade
# Out:
#       Country_Code                    Country_Name  year  tem_change
# 11148          EST                         Estonia  2000       2.075
# 11155          FIN                         Finland  2000       2.040
# 11202          LTU                       Lithuania  2000       2.015
# 11196          LVA                          Latvia  2000       2.011
# 11287          SJM  Svalbard and Jan Mayen Islands  2000       1.976
# 11095          BLR                         Belarus  2000       1.922
# 11135          CZE                         Czechia  2000       1.913
# 11250          POL                          Poland  2000       1.885
# 11276          SVN                        Slovenia  2000       1.804
# 11089          AUT                         Austria  2000       1.772

# %%
fourth_decade.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Decade_2000.csv', encoding='utf-8')

# %%
fifth = data.loc[data['year'] == '2010']
fifth
lo = fifth.nlargest(10, ['tem_change'])

# %%
lo.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Decade_2010.csv', encoding='utf-8')

# %%
res = data.pivot(index=["Country_Code", "Country_Name"], columns='year', values='tem_change')
res
# Out:
# year                                    NaN   1961   1962   1963  \
# Country_Code Country_Name
# NaN          Annex I countries          NaN  0.453  0.161  0.172
#              Asia                       NaN  0.049 -0.008  0.266
#              Australia and New Zealand  NaN  0.136  0.139 -0.122
#              Belgium-Luxembourg         NaN  0.872 -0.803 -1.171
#              Caribbean                  NaN -0.004 -0.027 -0.091
# ...                                     ...    ...    ...    ...
# X21          Americas                   NaN  0.052 -0.084  0.253
# YEM          Yemen                      NaN  0.033 -0.006  0.168
# ZAF          South Africa               NaN  0.267  0.229    NaN
# ZMB          Zambia                     NaN  0.239 -0.165 -0.385
# ZWE          Zimbabwe                   NaN  0.277  0.242 -0.453
#
# year                                    1963+A773:C16747   1964   1965   1966  \
# Country_Code Country_Name
# ...

# %%
df = pd.DataFrame(res)
df
# Out:
# year                                    NaN   1961   1962   1963  \
# Country_Code Country_Name
# NaN          Annex I countries          NaN  0.453  0.161  0.172
#              Asia                       NaN  0.049 -0.008  0.266
#              Australia and New Zealand  NaN  0.136  0.139 -0.122
#              Belgium-Luxembourg         NaN  0.872 -0.803 -1.171
#              Caribbean                  NaN -0.004 -0.027 -0.091
# ...                                     ...    ...    ...    ...
# X21          Americas                   NaN  0.052 -0.084  0.253
# YEM          Yemen                      NaN  0.033 -0.006  0.168
# ZAF          South Africa               NaN  0.267  0.229    NaN
# ZMB          Zambia                     NaN  0.239 -0.165 -0.385
# ZWE          Zimbabwe                   NaN  0.277  0.242 -0.453
#
# year                                    1963+A773:C16747   1964   1965   1966  \
# Country_Code Country_Name
# ...

# %%
#df.to_exc(r'C:\Users\Rimas\Desktop\Climate.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df.to_exc(r'C:\Users\Rimas\Desktop\Climate.csv', encoding='utf-8')
#
# File ~\anaconda3\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_exc'

# %%
df.reset_index(inplace=True)
df
# Out:
# year Country_Code               Country_Name  NaN   1961   1962   1963  \
# 0             NaN          Annex I countries  NaN  0.453  0.161  0.172
# 1             NaN                       Asia  NaN  0.049 -0.008  0.266
# 2             NaN  Australia and New Zealand  NaN  0.136  0.139 -0.122
# 3             NaN         Belgium-Luxembourg  NaN  0.872 -0.803 -1.171
# 4             NaN                  Caribbean  NaN -0.004 -0.027 -0.091
# ..            ...                        ...  ...    ...    ...    ...
# 569           X21                   Americas  NaN  0.052 -0.084  0.253
# 570           YEM                      Yemen  NaN  0.033 -0.006  0.168
# 571           ZAF               South Africa  NaN  0.267  0.229    NaN
# 572           ZMB                     Zambia  NaN  0.239 -0.165 -0.385
# 573           ZWE                   Zimbabwe  NaN  0.277  0.242 -0.453
#
# year  1963+A773:C16747   1964   1965   1966  ...   2010   2011   2012   2013  \
# ...

# %%
cont = (data.loc[data['Country_Name'].isin(['Africa','Europe', 'Antarctica', 'South America', 'Northern America', 'Asia', 'Australia'])])
cont
# Out:
#       Country_Code      Country_Name  year  tem_change
# 7              ATA        Antarctica  1961       0.280
# 12             AUS         Australia  1961       0.151
# 248            X06            Africa  1961      -0.017
# 255            NaN  Northern America  1961       0.017
# 258            NaN     South America  1961       0.116
# ...            ...               ...   ...         ...
# 16720          X06            Africa  2019       1.415
# 16727          NaN  Northern America  2019       1.179
# 16730          NaN     South America  2019       1.310
# 16731          NaN              Asia  2019       1.369
# 16737          NaN            Europe  2019       2.116
#
# [413 rows x 4 columns]

# %%
cont.to_csv(r'C:\Users\Rimas\Desktop\Visualization\project\Continente_temp.csv', encoding='utf-8')

# %%
data
# Out:
#       Country_Code                             Country_Name  year  tem_change
# 1              ALB                                  Albania  1961       0.631
# 2              DZA                                  Algeria  1961       0.186
# 3              ASM                           American Samoa  1961      -0.014
# 4              AND                                  Andorra  1961       0.749
# 5              AGO                                   Angola  1961       0.053
# ...            ...                                      ...   ...         ...
# 16751          NaN        Low Income Food Deficit Countries  2019       1.244
# 16752          NaN  Net Food Importing Developing Countries  2019       1.412
# 16753          NaN                        Annex I countries  2019       1.627
# 16754          NaN                    Non-Annex I countries  2019       1.361
# 16755          NaN                                     OECD  2019       1.297
#
# [16755 rows x 4 columns]
